# %%
import pandas as pd
import numpy as np

# %%
srcDF = pd.read_excel("cashflow.xlsx", parse_dates=[1], engine="openpyxl")

# %%
srcDF.head(10)
# Out:
#   offerte e commesse::codice_commessa data fatturazione prevista  \
# 0                              OIT044                 2022-01-31
# 1                              OIT052                 2022-01-31
# 2                              OIT033                 2022-02-28
# 3                              OIT039                 2022-02-28
# 4                              OIT043                 2022-02-28
# 5                              OIT048                 2022-02-28
# 6                              OIT049                 2022-02-28
# 7                              OIT050                 2022-02-28
# 8                              OIT051                 2022-02-28
# 9                              OIT006                 2022-03-31
#
#    importo acconto fatturato
# 0                   19250.00
# 1                   48500.00
# 2                   38250.00
# 3                   11200.00
# 4                    6300.00
# 5                    4000.00
# 6                   24000.00
# 7                   13000.00
# 8                    9763.35
# 9                    6500.00

# %%
df = srcDF.set_index(srcDF.iloc[:,0]).sort_index().iloc[:, 1:]

# %%
df.head(10)
# Out:
#                                     data fatturazione prevista  \
# offerte e commesse::codice_commessa
# OIT006                                              2022-03-31
# OIT006                                              2022-04-30
# OIT012                                              2022-03-31
# OIT012                                              2022-06-30
# OIT019                                              2022-03-31
# OIT024                                              2022-06-30
# OIT029                                              2022-03-31
# OIT029                                              2022-04-30
# OIT030                                              2022-06-30
# OIT033                                              2022-02-28
#
#                                      importo acconto fatturato
# offerte e commesse::codice_commessa
# OIT006                                                 6500.00
# OIT006                                                18500.00
# OIT012                                                10000.00
# OIT012                                                10110.00
# OIT019                                                19500.00
# OIT024                                                23247.39
# OIT029                                                10400.00
# OIT029                                                10413.35
# OIT030                                                  482.94
# OIT033                                                38250.00

# %%
current_year = 2022

# %%
prev_year_mask = df["data fatturazione prevista"].dt.year < current_year
curr_year_mask = df["data fatturazione prevista"].dt.year == current_year
next_year_mask = df["data fatturazione prevista"].dt.year > current_year

# %%
prev_year_total = df[prev_year_mask]["importo acconto fatturato"].sum()
next_year_total = df[next_year_mask]["importo acconto fatturato"].sum()

# %%
prev_year_total, next_year_total
# Out:
# (0.0, 0.0)

# %%
from util.calendar import int_month_to_str

currDF = df[curr_year_mask]
currDF["data fatturazione prevista"] =  (currDF["data fatturazione prevista"].dt.month).apply(int_month_to_str)

# %%
currDF.head(10)
# Out:
#                                     data fatturazione prevista  \
# offerte e commesse::codice_commessa
# OIT006                                                   Marzo
# OIT006                                                  Aprile
# OIT012                                                   Marzo
# OIT012                                                  Giugno
# OIT019                                                   Marzo
# OIT024                                                  Giugno
# OIT029                                                   Marzo
# OIT029                                                  Aprile
# OIT030                                                  Giugno
# OIT033                                                Febbraio
#
#                                      importo acconto fatturato
# offerte e commesse::codice_commessa
# OIT006                                                 6500.00
# OIT006                                                18500.00
# OIT012                                                10000.00
# OIT012                                                10110.00
# OIT019                                                19500.00
# OIT024                                                23247.39
# OIT029                                                10400.00
# OIT029                                                10413.35
# OIT030                                                  482.94
# OIT033                                                38250.00

# %%
for m in range(1, 13):
    month = int_month_to_str(m)
    month_mask = currDF["data fatturazione prevista"] == month
    currDF[month] = np.where(currDF["data fatturazione prevista"] == month, currDF["importo acconto fatturato"], 0)
    
currMonthly = currDF.groupby(currDF.index).sum()

# %%
currMonthly
# Out:
#                                      importo acconto fatturato  Gennaio  \
# offerte e commesse::codice_commessa
# OIT006                                                25000.00      0.0
# OIT012                                                20110.00      0.0
# OIT019                                                19500.00      0.0
# OIT024                                                23247.39      0.0
# OIT029                                                20813.35      0.0
# OIT030                                                  482.94      0.0
# OIT033                                               127500.00      0.0
# OIT037                                                19144.74      0.0
# OIT038                                                21109.31      0.0
# OIT039                                                31200.00      0.0
# OIT040                                                12500.00      0.0
# OIT042                                                40000.00      0.0
# OIT043                                                19358.83      0.0
# OIT044                                                38500.00  19250.0
# OIT048                                                20000.00      0.0
# OIT049                                                24000.00      0.0
# OIT050                                                13000.00      0.0
# OIT051                                                 9763.35      0.0
# OIT052                                                48500.00  48500.0
# OIT053                                                75000.00      0.0
#
#                                      Febbraio    Marzo    Aprile  Maggio  \
# offerte e commesse::codice_commessa
# OIT006                                   0.00   6500.0  18500.00     0.0
# OIT012                                   0.00  10000.0      0.00     0.0
# OIT019                                   0.00  19500.0      0.00     0.0
# OIT024                                   0.00      0.0      0.00     0.0
# OIT029                                   0.00  10400.0  10413.35     0.0
# OIT030                                   0.00      0.0      0.00     0.0
# OIT033                               38250.00  25500.0  63750.00     0.0
# OIT037                                   0.00      0.0      0.00     0.0
# OIT038                                   0.00  10555.0      0.00     0.0
# OIT039                               11200.00      0.0      0.00     0.0
# OIT040                                   0.00  10000.0      0.00     0.0
# OIT042                                   0.00  20000.0      0.00     0.0
# OIT043                                6300.00   6300.0      0.00     0.0
# OIT044                                   0.00      0.0      0.00     0.0
# OIT048                                4000.00      0.0   8000.00     0.0
# OIT049                               24000.00      0.0      0.00     0.0
# OIT050                               13000.00      0.0      0.00     0.0
# OIT051                                9763.35      0.0      0.00     0.0
# OIT052                                   0.00      0.0      0.00     0.0
# OIT053                                   0.00      0.0      0.00     0.0
#
#                                        Giugno   Luglio  Agosto  Settembre  \
# offerte e commesse::codice_commessa
# OIT006                                   0.00      0.0     0.0       0.00
# OIT012                               10110.00      0.0     0.0       0.00
# OIT019                                   0.00      0.0     0.0       0.00
# OIT024                               23247.39      0.0     0.0       0.00
# OIT029                                   0.00      0.0     0.0       0.00
# OIT030                                 482.94      0.0     0.0       0.00
# OIT033                                   0.00      0.0     0.0       0.00
# OIT037                               19144.74      0.0     0.0       0.00
# OIT038                                   0.00      0.0     0.0   10554.31
# OIT039                                   0.00      0.0     0.0   20000.00
# OIT040                                   0.00   2500.0     0.0       0.00
# OIT042                                   0.00      0.0     0.0   20000.00
# OIT043                                6758.83      0.0     0.0       0.00
# OIT044                                   0.00  19250.0     0.0       0.00
# OIT048                                8000.00      0.0     0.0       0.00
# OIT049                                   0.00      0.0     0.0       0.00
# OIT050                                   0.00      0.0     0.0       0.00
# OIT051                                   0.00      0.0     0.0       0.00
# OIT052                                   0.00      0.0     0.0       0.00
# OIT053                               75000.00      0.0     0.0       0.00
#
#                                      Ottobre  Novembre  Dicembre
# offerte e commesse::codice_commessa
# OIT006                                   0.0       0.0       0.0
# OIT012                                   0.0       0.0       0.0
# OIT019                                   0.0       0.0       0.0
# OIT024                                   0.0       0.0       0.0
# OIT029                                   0.0       0.0       0.0
# OIT030                                   0.0       0.0       0.0
# OIT033                                   0.0       0.0       0.0
# OIT037                                   0.0       0.0       0.0
# OIT038                                   0.0       0.0       0.0
# OIT039                                   0.0       0.0       0.0
# OIT040                                   0.0       0.0       0.0
# OIT042                                   0.0       0.0       0.0
# OIT043                                   0.0       0.0       0.0
# OIT044                                   0.0       0.0       0.0
# OIT048                                   0.0       0.0       0.0
# OIT049                                   0.0       0.0       0.0
# OIT050                                   0.0       0.0       0.0
# OIT051                                   0.0       0.0       0.0
# OIT052                                   0.0       0.0       0.0
# OIT053                                   0.0       0.0       0.0

# %%
currMonthly.to_excel("test.xlsx")
